# %%
f = open("input2.txt", "r")
Lines = f.readlines()
i = 0
for x in Lines:
    split = x.split()
    minmax = split[0].split("-")
    min = int(minmax[0])
    max = int(minmax[1])
    rule = split[1].replace(":","")
    password = split[2].replace(" ","")
    counting = password.count(rule)
    if counting >= min and counting <= max:
        i+=1


i = 0
for x in Lines:
    split = x.split()
    minmax = split[0].split("-")
    first = int(minmax[0])
    second = int(minmax[1])
    rule = split[1].replace(":", "")
    password = split[2].replace(" ", "")
    boolFirst = password[first-1:first] == rule
    boolSec = password[second-1:second] == rule
    print(first)
    print(second)
    print(rule)
    print(password)
    print(boolFirst)
    print(boolSec)
    if(boolFirst and not boolSec or boolSec and not boolFirst):
        print("One correct")
        i+=1


print(i)
# Out:
# 4
# 5
# l
# rllllj
# True
# True
# 4
# 10
# s
# ssskssphrlpscsxrfsr
# False
# False
# 14
# 18
# p
# ppppppppppppppppppp
# True
# True
# 1
# 6
# z
# zzlzvmqbzzclrz
# True
# False
# One correct
# 4
# 5
# j
# jhjjhxhjkxj
# True
# False
# One correct
# 7
# 8
# s
# tsszsssrmsss
# True
# False
# One correct
# 12
# 13
# m
# mmmmsmmmmmmqm
# False
# True
# One correct
# 16
# 17
# k
# kkkkkkkzkkkkrkkmfkk
# False
# False
# 6
# 7
# x
# jxxwxpx
# False
# True
# One correct
# 3
# 7
# w
# wwwwwwwwwwwwwwwwwwww
# True
# True
# 4
# 15
# h
# gcxfgbpbghdtrkhn
# False
# True
# One correct
# 3
# 4
# g
# tprznvggnfgpgtmzsrmr
# False
# False
# 16
# 17
# c
# cccccccccccccccwccc
# False
# True
# One correct
# 6
# 7
# s
# ssssssmsss
# True
# False
# One correct
# 3
# 4
# l
# flll
# True
# True
# 4
# 5
# v
# mvvvc
# True
# False
# One correct
# 17
# 19
# j
# lwjsfvkjgjjmsjrsjjr
# True
# False
# One correct
# 2
# 20
# k
# xhfhfzvghbkbngzbqcck
# False
# True
# One correct
# 2
# 3
# s
# rssnsxslshrdtk
# True
# ...
